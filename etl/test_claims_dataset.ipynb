# %%
import pandas as pd
from pathlib import Path

file = Path(
    "../data/processed/primary/"
    "Carrier_Claims_Features.csv"
)

carrier = pd.read_csv(file)

print("Shape:", carrier.shape)
print("\nColumns:")
print(carrier.columns.tolist())

print("\nData types:")
print(carrier.dtypes)

print("\nMissing values:")
print(carrier.isna().sum())

print("\nNumeric summary:")
print(carrier.describe())
# Out:
# Shape: (4741335, 21)
#
# Columns:
# ['CLM_ID', 'DESYNPUF_ID', 'total_claim_payment_amt', 'total_allowed_charge_amt', 'total_deductible_amt', 'total_coinsurance_amt', 'total_primary_payer_paid_amt', 'avg_payment_per_line', 'payment_to_allowed_ratio', 'line_count', 'unique_hcpcs_count', 'max_line_payment', 'diagnosis_count', 'unique_diagnosis_count', 'primary_provider_npi', 'distinct_provider_count_on_claim', 'provider_claim_volume', 'provider_avg_claim_payment', 'claim_year', 'claim_month', 'claim_day_of_week']
#
# Data types:
# CLM_ID                                int64
# DESYNPUF_ID                          object
# total_claim_payment_amt             float64
# total_allowed_charge_amt            float64
# total_deductible_amt                float64
# total_coinsurance_amt               float64
# total_primary_payer_paid_amt        float64
# avg_payment_per_line                float64
# payment_to_allowed_ratio            float64
# line_count                            int64
# ...
